# %%
import numpy as np
import pandas as pd

import os

for dirname, _, filenames in os.walk('/icislab/volume1/wjl/eeg'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Shape of train, val and test should be (nr_samples, 23, 256)
# Every sample of data represents 1 second taken from 23 channels with 256-bit rate
npz_file = np.load('/icislab/volume1/wjl/eeg/chbmit/eeg-seizure_train.npz', allow_pickle=True)
#npz_file = np.load('/kaggle/input/chbmitseizuredataset/eeg-seizure_train.npz', allow_pickle=True)
signals_train = npz_file['train_signals']
labels_train = npz_file['train_labels']

l_dict = {}
for a in range(37666):
    k = labels_train[a]
    if k == 1 :
        l_dict[a] = 'Y'
    else:
        l_dict[a] = 'N'

s = signals_train[:, :, 1]
length = s.shape[0]
print(length)
print('Train data shape is {}'.format(signals_train.shape))
print('Labels shape for train is {}'.format(labels_train.shape))
print("npz : ",npz_file)
# Out:
# /icislab/volume1/wjl/eeg/chbmit/eeg-seizure_test.npz
# /icislab/volume1/wjl/eeg/chbmit/eeg-seizure_val.npz
# /icislab/volume1/wjl/eeg/chbmit/eeg-seizure_train.npz
# 37666
# Train data shape is (37666, 23, 256)
# Labels shape for train is (37666,)
# npz :  <numpy.lib.npyio.NpzFile object at 0x7fe666288350>

# %%
import os
import time
import pywt
import cv2
import json
import pickle
import itertools
import operator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.io import loadmat
from tqdm import tqdm
from scipy import signal
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
# from stockwell import st
from scipy.signal import chirp

# %%
def most_common(L):
    # get an iterable of (item, iterable) pairs
    SL = sorted((x, i) for i, x in enumerate(L))
    # print 'SL:', SL
    groups = itertools.groupby(SL, key=operator.itemgetter(0))
    # auxiliary function to get "quality" for an item
    def _auxfun(g):
        item, iterable = g
        count = 0
        min_index = len(L)
        for _, where in iterable:
            count += 1
            min_index = min(min_index, where)
        # print 'item %r, count %r, minind %r' % (item, count, min_index)
        return count, -min_index
        # pick the highest-count/earliest item
    return max(groups, key=_auxfun)[0]

# %%
save_path = '/icislab/volume1/wjl/eeg/'

mitbih_path = '/icislab/volume1/wjl/eeg/chbmit/'

df = pd.read_excel('/icislab/volume1/wjl/ecg/data/mit-bih/train/ECG_Data_Collect.xlsx')

if not os.path.exists(os.path.join(save_path,'chbmit_rl')):
    os.mkdir(os.path.join(save_path,'chbmit_rl'))

save_path = os.path.join(save_path, 'chbmit_rl')



if not os.path.exists(os.path.join(save_path,'train')):
    os.mkdir(os.path.join(save_path,'train'))
if not os.path.exists(os.path.join(save_path,'val')):
    os.mkdir(os.path.join(save_path,'val'))
    
if not os.path.exists(os.path.join(save_path,'train','images')):
    os.mkdir(os.path.join(save_path,'train','images'))
if not os.path.exists(os.path.join(save_path,'val','images')):
    os.mkdir(os.path.join(save_path,'val','images'))
    
if not os.path.exists(os.path.join(save_path,'train','images_full')):
    os.mkdir(os.path.join(save_path,'train','images_full'))
if not os.path.exists(os.path.join(save_path,'val','images_full')):
    os.mkdir(os.path.join(save_path,'val','images_full'))

for i in ['stft','cwt']:
    if not os.path.exists(os.path.join(save_path,'train','images',i)):
        os.mkdir(os.path.join(save_path,'train','images',i))
    if not os.path.exists(os.path.join(save_path,'val','images',i)):
        os.mkdir(os.path.join(save_path,'val','images',i))
        
    if not os.path.exists(os.path.join(save_path,'train','images_full',i)):
        os.mkdir(os.path.join(save_path,'train','images_full',i))
    if not os.path.exists(os.path.join(save_path,'val','images_full',i)):
        os.mkdir(os.path.join(save_path,'val','images_full',i))
    
if not os.path.exists(os.path.join(save_path,'train','ecg')):
    os.mkdir(os.path.join(save_path,'train','ecg'))
if not os.path.exists(os.path.join(save_path,'val','ecg')):
    os.mkdir(os.path.join(save_path,'val','ecg'))

# %%
            start += STEP
            end += STEP
eeg_train = {}
eeg_val = {}

eeg_train['data'] = train
eeg_val['data'] = val
eeg_train['labels'] = n2l
eeg_val['labels'] = n2l
print(eeg_train)

with open(os.path.join(save_path, 'train', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_train, f, indent=2)

with open(os.path.join(save_path, 'val', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_val, f, indent=2) = 360
STEP = 3600
win_sz = 72
overlap = 36

outer_win_sz = 180
outer_overlap = 90

zero = 1024
inner_step = 360
widths = np.concatenate([np.flip(np.arange(1, 181)),np.arange(1, 181)])
outer_widths = np.concatenate([np.flip(np.arange(1, 721)),np.arange(1, 721)])
g_dict = {'M':[0,1],'F':[1,0]}

l2n = {'N':0, 'Y':1}

n2l = {0:'N', 1:'Y'}

train = []
val = []

win = signal.windows.hann(win_sz)
outer_win = signal.windows.hann(outer_win_sz)
name = 0
l_defaullt = '~'
for j in tqdm(range(0,2,1)):
    i = df['record'][j]
    #print(i)
    
    
    
    if os.path.exists(os.path.join(mitbih_path,str(i) + '.pkl')):
        with open(os.path.join(mitbih_path,str(i) + '.pkl'), 'rb') as f:
            data = pickle.load(f)
        w = np.load(os.path.join(mitbih_path,str(i) + '.npy'))
        print("w_npy:",w)
        print(w.shape)
        print("data_pkl",data)
        l_dict = {}
        #print(data[[:,1]])
        for a in data:
            #print(a[1])
            if a[1] in ['N', 'L', 'R', 'V', 'A']:
                l_dict[a[0]] = a[1]
            else:
                l_dict[a[0]] = '~'

        #print(l_dict)
        s = w[:,1]
        g = g_dict[df['Sex'][j]] 
        age = 0
        if df['Age'][j] > 0 and df['Age'][j] < 100:
            age = df['Age'][j]/100
            
        
        #    break
        length = s.shape[0]
        start = 0
        end = STEP
        #     for i in range(0,int(np.floor(length/STEP))):
        while end < length:

            sample = {}
            
            inner_start = start
            inner_end = start+inner_step
            
            segment_images = []
            segment_ecg = []
            segment_id = 0
            f,t,zxx = signal.stft(s[start : end]-zero,fs, window=outer_win, nperseg=outer_win_sz, noverlap=outer_overlap, nfft=outer_win_sz, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
                # plt.figure(figsize=(33,21))
            fig = Figure()
            fig.subplots_adjust(0,0,1,1)
                #         fig.add_axes([0,0,1,1])
            canvas = FigureCanvas(fig)
            ax = fig.gca()
            ax.pcolormesh(t, f, 20*np.log10(np.abs(zxx)), shading='gouraud')
            ax.axis('off')
            canvas.draw()
            width, height = fig.get_size_inches() * fig.get_dpi()
            image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)
            
            cwt = signal.cwt(s[start:end]-zero,signal.ricker,outer_widths)
            labels = []
            
            if name%10 == 0:
                plt.imsave(os.path.join(save_path,'val','images_full','cwt',str(name)+'.jpg'),cwt)
                cwt = plt.imread(os.path.join(save_path,'val','images_full','cwt',str(name)+'.jpg'))
                cwt = cv2.resize(cwt,(224,224))
                plt.imsave(os.path.join(save_path,'val','images_full','cwt',str(name)+'.jpg'),cwt)
                c = cv2.resize(image,(224,224))
                plt.imsave(os.path.join(save_path,'val','images_full','stft',str(name)+'.jpg'),c)
                
            else:
                plt.imsave(os.path.join(save_path,'train','images_full','cwt',str(name)+'.jpg'),cwt)
                cwt = plt.imread(os.path.join(save_path,'train','images_full','cwt',str(name)+'.jpg'))
                cwt = cv2.resize(cwt,(224,224))
                plt.imsave(os.path.join(save_path,'train','images_full','cwt',str(name)+'.jpg'),cwt)
                c = cv2.resize(image,(224,224))
                plt.imsave(os.path.join(save_path,'train','images_full','stft',str(name)+'.jpg'),c)
            while inner_end <= end:
            
                f,t,zxx = signal.stft(s[inner_start : inner_end]-zero,fs, window=win, nperseg=win_sz, noverlap=overlap, nfft=win_sz, return_onesided=True, boundary='zeros', padded=True, axis=- 1)
                    # plt.figure(figsize=(33,21))
                fig = Figure()
                fig.subplots_adjust(0,0,1,1)
                    #         fig.add_axes([0,0,1,1])
                canvas = FigureCanvas(fig)
                ax = fig.gca()
                ax.pcolormesh(t, f, 20*np.log10(np.abs(zxx)), shading='gouraud')
                ax.axis('off')
                canvas.draw()
                width, height = fig.get_size_inches() * fig.get_dpi()
                image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)
                
                cwt = signal.cwt(s[inner_start:inner_end]-zero,signal.ricker,outer_widths)
                segment_ecg.append(str(name)+'_'+str(segment_id)+'.npy')
                segment_images.append(str(name)+'_'+str(segment_id)+'.jpg')
                if name%10 == 0:
                    plt.imsave(os.path.join(save_path,'val','images','cwt',str(name)+'_'+str(segment_id)+'.jpg'),cwt)
                    cwt = plt.imread(os.path.join(save_path,'val','images','cwt',str(name)+'_'+str(segment_id)+'.jpg'))
                    cwt = cv2.resize(cwt,(224,224))
                    plt.imsave(os.path.join(save_path,'val','images','cwt',str(name)+'_'+str(segment_id)+'.jpg'),cwt)
                    c = cv2.resize(image,(224,224))
                    plt.imsave(os.path.join(save_path,'val','images','stft',str(name)+'_'+str(segment_id)+'.jpg'),c)
                    np.save(os.path.join(save_path,'val','ecg',str(name)+'_'+str(segment_id)+'.npy'),s[inner_start : inner_end]-zero)
                else:
                    plt.imsave(os.path.join(save_path,'train','images','cwt',str(name)+'_'+str(segment_id)+'.jpg'),cwt)
                    cwt = plt.imread(os.path.join(save_path,'train','images','cwt',str(name)+'_'+str(segment_id)+'.jpg'))
                    cwt = cv2.resize(cwt,(224,224))
                    plt.imsave(os.path.join(save_path,'train','images','cwt',str(name)+'_'+str(segment_id)+'.jpg'),cwt)
                    c = cv2.resize(image,(224,224))
                    plt.imsave(os.path.join(save_path,'train','images','stft',str(name)+'_'+str(segment_id)+'.jpg'),c)
                    np.save(os.path.join(save_path,'train','ecg',str(name)+'_'+str(segment_id)+'.npy'),s[inner_start : inner_end]-zero)
                label_list = []
                
                #n=list(l_dict.keys())
                #print('l_dict.key : ',n)
                #print('l_dict18 :',l_dict['18'])
                for k in range(inner_start,inner_end):
                    #print('k: ',k)
                    #print("-----")
                   # if k in list(l_dict.keys()):
                    if str(k) in l_dict.keys():
                       # print(k)
                        label_list.append(l_dict[str(k)])
                        #print('l_dict[k]',l_dict[str(k)])
                
                #print('label_list :',label_list)
                default_label='~' 
                
                #print(len(label_list))
                if len(label_list) == 0:
                    l = default_label
                else:
                    l = most_common(label_list)
                    default_label = l
                #print('l :',l)
                #print('l2nl :',l2n[l])
                labels.append(l2n[l])
                segment_id += 1
                inner_start += inner_step
                inner_end += inner_step
#             key = list(l_dict.keys())[0]
#             label_list = []
#             for k in range(start,end):
#                 if k in list(l_dict.keys()):
#                     label_list.append(l_dict[k])
            
#             l = most_common(label_list)
            
            sample['images'] = segment_images
            sample['images_full'] = str(name)+'.jpg'
            sample['ecg'] = segment_ecg
            sample['id'] = name
            sample['label'] = labels
            sample['age'] = age
            sample['gender'] = g
            if name%10 == 0:
                val.append(sample)
            else:
                train.append(sample)

            name += 1
            startDD += STE
            end += STEP
ecg_train = {}
ecg_val = {}


ecg_train['data'] = train
ecg_val['data'] = val
ecg_train['labels'] = n2l
ecg_val['labels'] = n2l
print(ecg_train)

with open(os.path.join(save_path,'train','ecg_labels.json'),'w') as f:
    json.dump(ecg_train,f,indent=2)

with open(os.path.join(save_path,'val','ecg_labels.json'),'w') as f:
    json.dump(ecg_val,f,indent=2)

# %%
fs = 36
STEP = 360
win_sz = 72
overlap = 36

outer_win_sz = 180
outer_overlap = 90

zero = 1024
inner_step = 360
widths = np.concatenate([np.flip(np.arange(1, 181)), np.arange(1, 181)])
outer_widths = np.concatenate([np.flip(np.arange(1, 721)), np.arange(1, 721)])
g_dict = {'M': [0, 1], 'F': [1, 0]}

l2n = {'N': 0, 'Y': 1}

n2l = {0: 'N', 1: 'Y'}

train = []
val = []

win = signal.windows.hann(win_sz)
outer_win = signal.windows.hann(outer_win_sz)
name = 0
l_defaullt = '~'
#for j in tqdm(range(0, 2, 1)):
#    i = df['record'][j]

for dirname, _, filenames in os.walk('/icislab/volume1/wjl/eeg'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

npz_file = np.load('/icislab/volume1/wjl/eeg/chbmit/eeg-seizure_train.npz', allow_pickle=True)

signals_train = npz_file['train_signals']
labels_train = npz_file['train_labels']
    #if os.path.exists(os.path.join(mitbih_path, str(i) + '.pkl')):
        #with open(os.path.join(mitbih_path, str(i) + '.pkl'), 'rb') as f:
        #    data = pickle.load(f)
        #w = np.load(os.path.join(mitbih_path, str(i) + '.npy'))
        #print("w_npy:", w)
        #print(w.shape)
        #print("data_pkl", data)
        data = labels_train
        w = signals_train
        l_dict = {}
        for a in range(37666):
            k = labels_train[a]
            if k == 1 :
               l_dict[a] = 'Y'
            else:
               l_dict[a] = 'N'
        # print(l_dict)
        s = signals_train[:, :, 1]

        g = g_dict[df['Sex'][j]]
        age = 0
        if df['Age'][j] > 0 and df['Age'][j] < 100:
            age = df['Age'][j] / 100

        #    break
        length = s.shape[0]
        start = 0
        end = STEP
        #     for i in range(0,int(np.floor(length/STEP))):
        while end < length:

            sample = {}

            inner_start = start
            inner_end = start + inner_step

            segment_images = []
            segment_ecg = []
            segment_id = 0
            f, t, zxx = signal.stft(s[start: end] - zero, fs, window=outer_win, nperseg=outer_win_sz,
                                    noverlap=outer_overlap, nfft=outer_win_sz, return_onesided=True, boundary='zeros',
                                    padded=True, axis=- 1)
            # plt.figure(figsize=(33,21))
            fig = Figure()
            fig.subplots_adjust(0, 0, 1, 1)
            #         fig.add_axes([0,0,1,1])
            canvas = FigureCanvas(fig)
            ax = fig.gca()
            ax.pcolormesh(t, f, 20 * np.log10(np.abs(zxx)), shading='gouraud')
            ax.axis('off')
            canvas.draw()
            width, height = fig.get_size_inches() * fig.get_dpi()
            image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)

            cwt = signal.cwt(s[start:end] - zero, signal.ricker, outer_widths)
            labels = []

            if name % 10 == 0:
                plt.imsave(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
                cwt = plt.imread(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'))
                cwt = cv2.resize(cwt, (224, 224))
                plt.imsave(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
                c = cv2.resize(image, (224, 224))
                plt.imsave(os.path.join(save_path, 'val', 'images_full', 'stft', str(name) + '.jpg'), c)

            else:
                plt.imsave(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
                cwt = plt.imread(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'))
                cwt = cv2.resize(cwt, (224, 224))
                plt.imsave(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
                c = cv2.resize(image, (224, 224))
                plt.imsave(os.path.join(save_path, 'train', 'images_full', 'stft', str(name) + '.jpg'), c)
            while inner_end <= end:

                f, t, zxx = signal.stft(s[inner_start: inner_end] - zero, fs, window=win, nperseg=win_sz,
                                        noverlap=overlap, nfft=win_sz, return_onesided=True, boundary='zeros',
                                        padded=True, axis=- 1)
                # plt.figure(figsize=(33,21))
                fig = Figure()
                fig.subplots_adjust(0, 0, 1, 1)
                #         fig.add_axes([0,0,1,1])
                canvas = FigureCanvas(fig)
                ax = fig.gca()
                ax.pcolormesh(t, f, 20 * np.log10(np.abs(zxx)), shading='gouraud')
                ax.axis('off')
                canvas.draw()
                width, height = fig.get_size_inches() * fig.get_dpi()
                image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)

                cwt = signal.cwt(s[inner_start:inner_end] - zero, signal.ricker, outer_widths)
                segment_ecg.append(str(name) + '_' + str(segment_id) + '.npy')
                segment_images.append(str(name) + '_' + str(segment_id) + '.jpg')
                if name % 10 == 0:
                    plt.imsave(
                        os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                        cwt)
                    cwt = plt.imread(
                        os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'))
                    cwt = cv2.resize(cwt, (224, 224))
                    plt.imsave(
                        os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                        cwt)
                    c = cv2.resize(image, (224, 224))
                    plt.imsave(
                        os.path.join(save_path, 'val', 'images', 'stft', str(name) + '_' + str(segment_id) + '.jpg'), c)
                    np.save(os.path.join(save_path, 'val', 'ecg', str(name) + '_' + str(segment_id) + '.npy'),
                            s[inner_start: inner_end] - zero)
                else:
                    plt.imsave(
                        os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                        cwt)
                    cwt = plt.imread(
                        os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'))
                    cwt = cv2.resize(cwt, (224, 224))
                    plt.imsave(
                        os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                        cwt)
                    c = cv2.resize(image, (224, 224))
                    plt.imsave(
                        os.path.join(save_path, 'train', 'images', 'stft', str(name) + '_' + str(segment_id) + '.jpg'),
                        c)
                    np.save(os.path.join(save_path, 'train', 'ecg', str(name) + '_' + str(segment_id) + '.npy'),
                            s[inner_start: inner_end] - zero)
                label_list = []

                # n=list(l_dict.keys())
                # print('l_dict.key : ',n)
                # print('l_dict18 :',l_dict['18'])
                for k in range(inner_start, inner_end):
                    # print('k: ',k)
                    # print("-----")
                    # if k in list(l_dict.keys()):
                    if k in l_dict.keys():
                        # print(k)
                        label_list.append(l_dict[k])
                        # print('l_dict[k]',l_dict[str(k)])

                # print('label_list :',label_list)
                default_label = '~'

                # print(len(label_list))
                if len(label_list) == 0:
                    l = default_label
                else:
                    l = most_common(label_list)
                    default_label = l
                # print('l :',l)
                # print('l2nl :',l2n[l])
                labels.append(l2n[l])
                segment_id += 1
                inner_start += inner_step
                inner_end += inner_step

            sample['images'] = segment_images
            sample['images_full'] = str(name) + '.jpg'
            sample['ecg'] = segment_ecg
            sample['id'] = name
            sample['label'] = labels
            sample['age'] = age
            sample['gender'] = g
            if name % 10 == 0:
                val.append(sample)
            else:
                train.append(sample)

            name += 1
            start += STEP
            end += STEP
eeg_train = {}
eeg_val = {}

eeg_train['data'] = train
eeg_val['data'] = val
eeg_train['labels'] = n2l
eeg_val['labels'] = n2l
print(eeg_train)

with open(os.path.join(save_path, 'train', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_train, f, indent=2)

with open(os.path.join(save_path, 'val', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_val, f, indent=2)
# Out:
#   File "/tmp/ipykernel_5980/4270232929.py", line 44
#     data = labels_train
#     ^
# IndentationError: unexpected indent

# %%
fs = 36
STEP = 360
win_sz = 72
overlap = 36

outer_win_sz = 180
outer_overlap = 90

zero = 1024
inner_step = 360
widths = np.concatenate([np.flip(np.arange(1, 181)), np.arange(1, 181)])
outer_widths = np.concatenate([np.flip(np.arange(1, 721)), np.arange(1, 721)])
g_dict = {'M': [0, 1], 'F': [1, 0]}

l2n = {'N': 0, 'Y': 1}

n2l = {0: 'N', 1: 'Y'}

train = []
val = []

win = signal.windows.hann(win_sz)
outer_win = signal.windows.hann(outer_win_sz)
name = 0
l_defaullt = '~'
#for j in tqdm(range(0, 2, 1)):
#    i = df['record'][j]

for dirname, _, filenames in os.walk('/icislab/volume1/wjl/eeg'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

npz_file = np.load('/icislab/volume1/wjl/eeg/chbmit/eeg-seizure_train.npz', allow_pickle=True)

signals_train = npz_file['train_signals']
labels_train = npz_file['train_labels']
data = labels_train
w = signals_train
l_dict = {}
for a in range(37666):
    k = labels_train[a]
    if k == 1 :
        l_dict[a] = 'Y'
    else:
         l_dict[a] = 'N'
        # print(l_dict)
s = signals_train[:, :, 1]
g = g_dict[df['Sex'][j]]
age = 0
if df['Age'][j] > 0 and df['Age'][j] < 100:
   age = df['Age'][j] / 100

length = s.shape[0]
start = 0
end = STEP
        #     for i in range(0,int(np.floor(length/STEP))):
while end < length:

    sample = {}

    inner_start = start
    inner_end = start + inner_step

    segment_images = []
    segment_ecg = []
    segment_id = 0
    f, t, zxx = signal.stft(s[start: end] - zero, fs, window=outer_win, nperseg=outer_win_sz,
                            noverlap=outer_overlap, nfft=outer_win_sz, return_onesided=True, boundary='zeros',
                            padded=True, axis=- 1)
    # plt.figure(figsize=(33,21))
    fig = Figure()
    fig.subplots_adjust(0, 0, 1, 1)
    #         fig.add_axes([0,0,1,1])
    canvas = FigureCanvas(fig)
    ax = fig.gca()
    ax.pcolormesh(t, f, 20 * np.log10(np.abs(zxx)), shading='gouraud')
    ax.axis('off')
    canvas.draw()
    width, height = fig.get_size_inches() * fig.get_dpi()
    image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)

    cwt = signal.cwt(s[start:end] - zero, signal.ricker, outer_widths)
    labels = []

    if name % 10 == 0:
        plt.imsave(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
        cwt = plt.imread(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'))
        cwt = cv2.resize(cwt, (224, 224))
        plt.imsave(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
        c = cv2.resize(image, (224, 224))
        plt.imsave(os.path.join(save_path, 'val', 'images_full', 'stft', str(name) + '.jpg'), c)

    else:
        plt.imsave(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
        cwt = plt.imread(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'))
        cwt = cv2.resize(cwt, (224, 224))
        plt.imsave(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
        c = cv2.resize(image, (224, 224))
        plt.imsave(os.path.join(save_path, 'train', 'images_full', 'stft', str(name) + '.jpg'), c)
    while inner_end <= end:

        f, t, zxx = signal.stft(s[inner_start: inner_end] - zero, fs, window=win, nperseg=win_sz,
                                noverlap=overlap, nfft=win_sz, return_onesided=True, boundary='zeros',
                                padded=True, axis=- 1)
        # plt.figure(figsize=(33,21))
        fig = Figure()
        fig.subplots_adjust(0, 0, 1, 1)
        #         fig.add_axes([0,0,1,1])
        canvas = FigureCanvas(fig)
        ax = fig.gca()
        ax.pcolormesh(t, f, 20 * np.log10(np.abs(zxx)), shading='gouraud')
        ax.axis('off')
        canvas.draw()
        width, height = fig.get_size_inches() * fig.get_dpi()
        image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)

        cwt = signal.cwt(s[inner_start:inner_end] - zero, signal.ricker, outer_widths)
        segment_ecg.append(str(name) + '_' + str(segment_id) + '.npy')
        segment_images.append(str(name) + '_' + str(segment_id) + '.jpg')
        if name % 10 == 0:
            plt.imsave(
                os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                cwt)
            cwt = plt.imread(
                os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'))
            cwt = cv2.resize(cwt, (224, 224))
            plt.imsave(
                os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                cwt)
            c = cv2.resize(image, (224, 224))
            plt.imsave(
                os.path.join(save_path, 'val', 'images', 'stft', str(name) + '_' + str(segment_id) + '.jpg'), c)
            np.save(os.path.join(save_path, 'val', 'ecg', str(name) + '_' + str(segment_id) + '.npy'),
                    s[inner_start: inner_end] - zero)
        else:
            plt.imsave(
                os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                cwt)
            cwt = plt.imread(
                os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'))
            cwt = cv2.resize(cwt, (224, 224))
            plt.imsave(
                os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                cwt)
            c = cv2.resize(image, (224, 224))
            plt.imsave(
                os.path.join(save_path, 'train', 'images', 'stft', str(name) + '_' + str(segment_id) + '.jpg'),
                c)
            np.save(os.path.join(save_path, 'train', 'ecg', str(name) + '_' + str(segment_id) + '.npy'),
                    s[inner_start: inner_end] - zero)
        label_list = []

        # n=list(l_dict.keys())
        # print('l_dict.key : ',n)
        # print('l_dict18 :',l_dict['18'])
        for k in range(inner_start, inner_end):
            # print('k: ',k)
            # print("-----")
            # if k in list(l_dict.keys()):
            if k in l_dict.keys():
                # print(k)
                label_list.append(l_dict[k])
                # print('l_dict[k]',l_dict[str(k)])

        # print('label_list :',label_list)
        default_label = '~'

        # print(len(label_list))
        if len(label_list) == 0:
            l = default_label
        else:
            l = most_common(label_list)
            default_label = l
        # print('l :',l)
        # print('l2nl :',l2n[l])
        labels.append(l2n[l])
        segment_id += 1
        inner_start += inner_step
        inner_end += inner_step

    sample['images'] = segment_images
    sample['images_full'] = str(name) + '.jpg'
    sample['ecg'] = segment_ecg
    sample['id'] = name
    sample['label'] = labels
    sample['age'] = age
    sample['gender'] = g
    if name % 10 == 0:
        val.append(sample)
    else:
        train.append(sample)

    name += 1
    start += STEP
    end += STEP
eeg_train = {}
eeg_val = {}

eeg_train['data'] = train
eeg_val['data'] = val
eeg_train['labels'] = n2l
eeg_val['labels'] = n2l
print(eeg_train)

with open(os.path.join(save_path, 'train', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_train, f, indent=2)

with open(os.path.join(save_path, 'val', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_val, f, indent=2)
# Out:
# /icislab/volume1/wjl/eeg/chbmit/eeg-seizure_test.npz
# /icislab/volume1/wjl/eeg/chbmit/eeg-seizure_val.npz
# /icislab/volume1/wjl/eeg/chbmit/eeg-seizure_train.npz
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg_labels.json
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg_labels.json
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_25161/465491808.py in <module>
#      46         # print(l_dict)
#      47 s = signals_train[:, :, 1]
# ---> 48 g = g_dict[df['Sex'][j]]
#      49 age = 0
#      50 if df['Age'][j] > 0 and df['Age'][j] < 100:
#
# NameError: name 'j' is not defined

# %%
fs = 36
STEP = 360
win_sz = 72
overlap = 36

outer_win_sz = 180
outer_overlap = 90

zero = 1024
inner_step = 360
widths = np.concatenate([np.flip(np.arange(1, 181)), np.arange(1, 181)])
outer_widths = np.concatenate([np.flip(np.arange(1, 721)), np.arange(1, 721)])
g_dict = {'M': [0, 1], 'F': [1, 0]}

l2n = {'N': 0, 'Y': 1}

n2l = {0: 'N', 1: 'Y'}

train = []
val = []

win = signal.windows.hann(win_sz)
outer_win = signal.windows.hann(outer_win_sz)
name = 0
l_defaullt = '~'
#for j in tqdm(range(0, 2, 1)):
#    i = df['record'][j]

for dirname, _, filenames in os.walk('/icislab/volume1/wjl/eeg'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

npz_file = np.load('/icislab/volume1/wjl/eeg/chbmit/eeg-seizure_train.npz', allow_pickle=True)

signals_train = npz_file['train_signals']
labels_train = npz_file['train_labels']
data = labels_train
w = signals_train
l_dict = {}
for a in range(37666):
    k = labels_train[a]
    if k == 1 :
        l_dict[a] = 'Y'
    else:
         l_dict[a] = 'N'
        # print(l_dict)
s = signals_train[:, :, 1]
g = g_dict[df['Sex'][j]]
age = 0
if df['Age'][j] > 0 and df['Age'][j] < 100:
   age = df['Age'][j] / 100

length = s.shape[0]
start = 0
end = STEP
        #     for i in range(0,int(np.floor(length/STEP))):
    while end < length:

            sample = {}

            inner_start = start
            inner_end = start + inner_step

            segment_images = []
            segment_ecg = []
            segment_id = 0
            f, t, zxx = signal.stft(s[start: end] - zero, fs, window=outer_win, nperseg=outer_win_sz,
                                    noverlap=outer_overlap, nfft=outer_win_sz, return_onesided=True, boundary='zeros',
                                    padded=True, axis=- 1)
            # plt.figure(figsize=(33,21))
            fig = Figure()
            fig.subplots_adjust(0, 0, 1, 1)
            #         fig.add_axes([0,0,1,1])
            canvas = FigureCanvas(fig)
            ax = fig.gca()
            ax.pcolormesh(t, f, 20 * np.log10(np.abs(zxx)), shading='gouraud')
            ax.axis('off')
            canvas.draw()
            width, height = fig.get_size_inches() * fig.get_dpi()
            image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)

            cwt = signal.cwt(s[start:end] - zero, signal.ricker, outer_widths)
            labels = []

            if name % 10 == 0:
                plt.imsave(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
                cwt = plt.imread(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'))
                cwt = cv2.resize(cwt, (224, 224))
                plt.imsave(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
                c = cv2.resize(image, (224, 224))
                plt.imsave(os.path.join(save_path, 'val', 'images_full', 'stft', str(name) + '.jpg'), c)

            else:
                plt.imsave(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
                cwt = plt.imread(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'))
                cwt = cv2.resize(cwt, (224, 224))
                plt.imsave(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
                c = cv2.resize(image, (224, 224))
                plt.imsave(os.path.join(save_path, 'train', 'images_full', 'stft', str(name) + '.jpg'), c)
            while inner_end <= end:

                f, t, zxx = signal.stft(s[inner_start: inner_end] - zero, fs, window=win, nperseg=win_sz,
                                        noverlap=overlap, nfft=win_sz, return_onesided=True, boundary='zeros',
                                        padded=True, axis=- 1)
                # plt.figure(figsize=(33,21))
                fig = Figure()
                fig.subplots_adjust(0, 0, 1, 1)
                #         fig.add_axes([0,0,1,1])
                canvas = FigureCanvas(fig)
                ax = fig.gca()
                ax.pcolormesh(t, f, 20 * np.log10(np.abs(zxx)), shading='gouraud')
                ax.axis('off')
                canvas.draw()
                width, height = fig.get_size_inches() * fig.get_dpi()
                image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)

                cwt = signal.cwt(s[inner_start:inner_end] - zero, signal.ricker, outer_widths)
                segment_ecg.append(str(name) + '_' + str(segment_id) + '.npy')
                segment_images.append(str(name) + '_' + str(segment_id) + '.jpg')
                if name % 10 == 0:
                    plt.imsave(
                        os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                        cwt)
                    cwt = plt.imread(
                        os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'))
                    cwt = cv2.resize(cwt, (224, 224))
                    plt.imsave(
                        os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                        cwt)
                    c = cv2.resize(image, (224, 224))
                    plt.imsave(
                        os.path.join(save_path, 'val', 'images', 'stft', str(name) + '_' + str(segment_id) + '.jpg'), c)
                    np.save(os.path.join(save_path, 'val', 'ecg', str(name) + '_' + str(segment_id) + '.npy'),
                            s[inner_start: inner_end] - zero)
                else:
                    plt.imsave(
                        os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                        cwt)
                    cwt = plt.imread(
                        os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'))
                    cwt = cv2.resize(cwt, (224, 224))
                    plt.imsave(
                        os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
                        cwt)
                    c = cv2.resize(image, (224, 224))
                    plt.imsave(
                        os.path.join(save_path, 'train', 'images', 'stft', str(name) + '_' + str(segment_id) + '.jpg'),
                        c)
                    np.save(os.path.join(save_path, 'train', 'ecg', str(name) + '_' + str(segment_id) + '.npy'),
                            s[inner_start: inner_end] - zero)
                label_list = []

                # n=list(l_dict.keys())
                # print('l_dict.key : ',n)
                # print('l_dict18 :',l_dict['18'])
                for k in range(inner_start, inner_end):
                    # print('k: ',k)
                    # print("-----")
                    # if k in list(l_dict.keys()):
                    if k in l_dict.keys():
                        # print(k)
                        label_list.append(l_dict[k])
                        # print('l_dict[k]',l_dict[str(k)])

                # print('label_list :',label_list)
                default_label = '~'

                # print(len(label_list))
                if len(label_list) == 0:
                    l = default_label
                else:
                    l = most_common(label_list)
                    default_label = l
                # print('l :',l)
                # print('l2nl :',l2n[l])
                labels.append(l2n[l])
                segment_id += 1
                inner_start += inner_step
                inner_end += inner_step

            sample['images'] = segment_images
            sample['images_full'] = str(name) + '.jpg'
            sample['ecg'] = segment_ecg
            sample['id'] = name
            sample['label'] = labels
            sample['age'] = age
            sample['gender'] = g
            if name % 10 == 0:
                val.append(sample)
            else:
                train.append(sample)

            name += 1
            start += STEP
            end += STEP
eeg_train = {}
eeg_val = {}

eeg_train['data'] = train
eeg_val['data'] = val
eeg_train['labels'] = n2l
eeg_val['labels'] = n2l
print(eeg_train)

with open(os.path.join(save_path, 'train', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_train, f, indent=2)

with open(os.path.join(save_path, 'val', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_val, f, indent=2)
# Out:
#   File "/tmp/ipykernel_25161/1830909541.py", line 57
#     while end < length:
#     ^
# IndentationError: unexpected indent

# %%
fs = 36
STEP = 360
win_sz = 7
overlap = 4

outer_win_sz = 18
outer_overlap = 9

zero = 1024
inner_step = 36
widths = np.concatenate([np.flip(np.arange(1, 181)), np.arange(1, 181)])
outer_widths = np.concatenate([np.flip(np.arange(1, 721)), np.arange(1, 721)])
g_dict = {'M': [0, 1], 'F': [1, 0]}

l2n = {'N': 0, 'Y': 1}

n2l = {0: 'N', 1: 'Y'}

train = []
val = []

win = signal.windows.hann(win_sz)
outer_win = signal.windows.hann(outer_win_sz)
name = 0
l_defaullt = '~'
#for j in tqdm(range(0, 2, 1)):
#    i = df['record'][j]

for dirname, _, filenames in os.walk('/icislab/volume1/wjl/eeg'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

npz_file = np.load('/icislab/volume1/wjl/eeg/chbmit/eeg-seizure_train.npz', allow_pickle=True)

signals_train = npz_file['train_signals']
labels_train = npz_file['train_labels']
data = labels_train
w = signals_train
l_dict = {}
for a in range(37666):
    k = labels_train[a]
    if k == 1 :
        l_dict[a] = 'Y'
    else:
         l_dict[a] = 'N'
        # print(l_dict)
s = signals_train[:, :, 1]
g = g_dict['M']
age = 0.05
#if df['Age'][j] > 0 and df['Age'][j] < 100:
#   age = df['Age'][j] / 100

length = s.shape[0]
start = 0
end = STEP
        #     for i in range(0,int(np.floor(length/STEP))):
while end < length:

    sample = {}

    inner_start = start
    inner_end = start + inner_step

    segment_images = []
    segment_ecg = []
    segment_id = 0
    f, t, zxx = signal.stft(s[start: end] - zero, fs, window=outer_win, nperseg=outer_win_sz,
                            noverlap=outer_overlap, nfft=outer_win_sz, return_onesided=True, boundary='zeros',
                            padded=True, axis=- 1)
    # plt.figure(figsize=(33,21))
    fig = Figure()
    fig.subplots_adjust(0, 0, 1, 1)
    #         fig.add_axes([0,0,1,1])
    canvas = FigureCanvas(fig)
    ax = fig.gca()
    ax.pcolormesh(t, f, 20 * np.log10(np.abs(zxx)), shading='gouraud')
    ax.axis('off')
    canvas.draw()
    width, height = fig.get_size_inches() * fig.get_dpi()
    image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)

    #cwt = signal.cwt(s[start:end] - zero, signal.ricker, outer_widths)
    labels = []

    if name % 10 == 0:
        #plt.imsave(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
        #cwt = plt.imread(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'))
        #cwt = cv2.resize(cwt, (224, 224))
       # plt.imsave(os.path.join(save_path, 'val', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
        c = cv2.resize(image, (224, 224))
        plt.imsave(os.path.join(save_path, 'val', 'images_full', 'stft', str(name) + '.jpg'), c)

    else:
       # plt.imsave(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
       # cwt = plt.imread(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'))
       # cwt = cv2.resize(cwt, (224, 224))
       # plt.imsave(os.path.join(save_path, 'train', 'images_full', 'cwt', str(name) + '.jpg'), cwt)
        c = cv2.resize(image, (224, 224))
        plt.imsave(os.path.join(save_path, 'train', 'images_full', 'stft', str(name) + '.jpg'), c)
    while inner_end <= end:

        f, t, zxx = signal.stft(s[inner_start: inner_end] - zero, fs, window=win, nperseg=win_sz,
                                noverlap=overlap, nfft=win_sz, return_onesided=True, boundary='zeros',
                                padded=True, axis=- 1)
        # plt.figure(figsize=(33,21))
        fig = Figure()
        fig.subplots_adjust(0, 0, 1, 1)
        #         fig.add_axes([0,0,1,1])
        canvas = FigureCanvas(fig)
        ax = fig.gca()
        ##ax.pcolormesh(t, f, 20 * np.log10(np.abs(zxx)), shading='gouraud')
        ax.axis('off')
        canvas.draw()
        width, height = fig.get_size_inches() * fig.get_dpi()
        image = np.frombuffer(canvas.tostring_rgb(), dtype='uint8').reshape(int(height), int(width), 3)

        #cwt = signal.cwt(s[inner_start:inner_end] - zero, signal.ricker, outer_widths)
        segment_ecg.append(str(name) + '_' + str(segment_id) + '.npy')
        segment_images.append(str(name) + '_' + str(segment_id) + '.jpg')
        if name % 10 == 0:
            ##plt.imsave(
           #     os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
           #     cwt)
            #cwt = plt.imread(
            #    os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'))
            #cwt = cv2.resize(cwt, (224, 224))
            #plt.imsave(
            #    os.path.join(save_path, 'val', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
            #    cwt)
            c = cv2.resize(image, (224, 224))
            plt.imsave(
                os.path.join(save_path, 'val', 'images', 'stft', str(name) + '_' + str(segment_id) + '.jpg'), c)
            np.save(os.path.join(save_path, 'val', 'ecg', str(name) + '_' + str(segment_id) + '.npy'),
                    s[inner_start: inner_end] - zero)
        else:
           # plt.imsave(
            #    os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
           #     cwt)
           # cwt = plt.imread(
            #    os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'))
            #cwt = cv2.resize(cwt, (224, 224))
           # plt.imsave(
            #    os.path.join(save_path, 'train', 'images', 'cwt', str(name) + '_' + str(segment_id) + '.jpg'),
            #    cwt)
            c = cv2.resize(image, (224, 224))
            plt.imsave(
                os.path.join(save_path, 'train', 'images', 'stft', str(name) + '_' + str(segment_id) + '.jpg'),
                c)
            np.save(os.path.join(save_path, 'train', 'ecg', str(name) + '_' + str(segment_id) + '.npy'),
                    s[inner_start: inner_end] - zero)
        label_list = []

        # n=list(l_dict.keys())
        # print('l_dict.key : ',n)
        # print('l_dict18 :',l_dict['18'])
        for k in range(inner_start, inner_end):
            # print('k: ',k)
            # print("-----")
            # if k in list(l_dict.keys()):
            if k in l_dict.keys():
                # print(k)
                label_list.append(l_dict[k])
                # print('l_dict[k]',l_dict[str(k)])

        # print('label_list :',label_list)
        default_label = '~'

        # print(len(label_list))
        if len(label_list) == 0:
            l = default_label
        else:
            l = most_common(label_list)
            default_label = l
        # print('l :',l)
        # print('l2nl :',l2n[l])
        labels.append(l2n[l])
        segment_id += 1
        inner_start += inner_step
        inner_end += inner_step

    sample['images'] = segment_images
    sample['images_full'] = str(name) + '.jpg'
    sample['ecg'] = segment_ecg
    sample['id'] = name
    sample['label'] = labels
    sample['age'] = age
    sample['gender'] = g
    if name % 10 == 0:
        val.append(sample)
    else:
        train.append(sample)

    name += 1
    start += STEP
    end += STEP
eeg_train = {}
eeg_val = {}

eeg_train['data'] = train
eeg_val['data'] = val
eeg_train['labels'] = n2l
eeg_val['labels'] = n2l
print(eeg_train)

with open(os.path.join(save_path, 'train', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_train, f, indent=2)

with open(os.path.join(save_path, 'val', 'eeg_labels.json'), 'w') as f:
    json.dump(eeg_val, f, indent=2)
# Out:
# /icislab/volume1/wjl/eeg/chbmit/eeg-seizure_test.npz
# /icislab/volume1/wjl/eeg/chbmit/eeg-seizure_val.npz
# /icislab/volume1/wjl/eeg/chbmit/eeg-seizure_train.npz
# /icislab/volume1/wjl/eeg/chbmit_rl/val/eeg_labels.json
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg_labels.json
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/60_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/20_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/40_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/100_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/0_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/90_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/80_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/50_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/10_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/30_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/ecg/70_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/70.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/20.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/10.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/80.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/50.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/30.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/100.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/40.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/90.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images_full/stft/60.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/100_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/70_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/40_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/20_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/0_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/90_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/30_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/50_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/60_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/10_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/val/images/stft/80_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/eeg_labels.json
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg_labels.json
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/84_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/27_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/62_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/21_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/62_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/31_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/3_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/17_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/52_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/89_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/38_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/19_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/72_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/96_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/3_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/76_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/18_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/87_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/92_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/88_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/17_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/86_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/45_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/75_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/16_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/58_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/1_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/61_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/35_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/11_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/69_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/27_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/7_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/43_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/96_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/99_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/46_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/99_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/78_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/52_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/101_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/89_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/2_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/85_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/57_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/98_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/33_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/15_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/79_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/56_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/54_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/16_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/67_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/83_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/51_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/11_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/52_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/2_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/6_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/77_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/33_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/79_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/46_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/45_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/16_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/52_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/47_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/34_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/22_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/21_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/49_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/7_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/48_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/83_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/16_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/101_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/61_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/41_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/25_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/36_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/46_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/56_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/76_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/95_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/26_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/84_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/73_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/32_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/28_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/83_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/53_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/91_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/43_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/46_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/52_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/22_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/6_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/27_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/22_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/91_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/46_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/84_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/16_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/53_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/101_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/32_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/34_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/85_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/64_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/78_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/19_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/18_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/55_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/86_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/66_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/31_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/13_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/66_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/97_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/63_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/79_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/14_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/69_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/4_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/54_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/85_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/65_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/52_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/15_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/35_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/29_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/47_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/31_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/58_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/77_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/8_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/61_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/34_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/65_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/51_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/101_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/82_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/54_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/82_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/82_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/66_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/79_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/37_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/21_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/39_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/12_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/103_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/87_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/51_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/86_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/69_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/38_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/84_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/79_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/9_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/53_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/13_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/97_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/63_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/38_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/49_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/55_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/29_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/62_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/88_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/89_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/73_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/12_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/73_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/73_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/93_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/67_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/37_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/95_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/88_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/1_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/87_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/76_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/24_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/16_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/4_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/89_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/83_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/48_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/35_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/96_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/5_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/78_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/28_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/35_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/74_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/3_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/92_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/88_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/11_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/86_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/19_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/13_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/7_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/102_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/34_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/64_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/101_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/17_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/94_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/27_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/97_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/94_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/58_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/95_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/61_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/41_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/95_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/86_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/97_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/69_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/81_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/85_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/64_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/49_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/92_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/103_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/36_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/33_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/9_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/31_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/42_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/95_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/29_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/103_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/69_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/28_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/28_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/25_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/98_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/101_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/63_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/42_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/93_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/38_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/23_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/45_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/57_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/38_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/31_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/32_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/29_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/19_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/102_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/32_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/7_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/49_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/37_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/48_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/27_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/93_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/7_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/83_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/41_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/43_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/75_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/32_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/63_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/13_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/42_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/38_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/56_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/92_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/94_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/68_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/68_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/88_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/11_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/87_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/62_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/83_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/44_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/99_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/26_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/44_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/96_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/54_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/85_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/19_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/68_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/72_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/82_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/68_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/78_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/25_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/27_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/55_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/67_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/86_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/35_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/71_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/101_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/4_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/29_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/68_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/82_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/39_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/99_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/13_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/7_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/23_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/101_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/65_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/95_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/32_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/92_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/66_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/28_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/28_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/82_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/65_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/81_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/54_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/74_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/85_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/77_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/93_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/33_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/9_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/74_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/41_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/45_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/73_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/24_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/39_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/98_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/95_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/48_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/31_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/59_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/52_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/41_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/97_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/17_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/55_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/4_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/62_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/87_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/1_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/5_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/22_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/46_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/89_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/14_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/4_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/26_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/98_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/81_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/24_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/35_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/53_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/62_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/24_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/91_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/76_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/6_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/9_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/75_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/33_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/69_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/91_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/48_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/17_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/3_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/81_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/78_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/58_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/101_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/75_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/65_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/68_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/39_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/72_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/56_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/15_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/39_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/4_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/103_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/91_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/72_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/46_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/13_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/31_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/14_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/5_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/15_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/21_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/92_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/55_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/52_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/74_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/66_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/75_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/56_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/24_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/43_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/64_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/54_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/71_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/97_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/2_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/95_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/11_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/102_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/3_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/74_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/62_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/8_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/71_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/36_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/44_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/103_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/13_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/98_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/16_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/27_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/58_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/32_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/83_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/12_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/37_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/5_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/76_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/33_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/29_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/64_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/41_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/102_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/96_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/85_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/26_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/63_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/67_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/22_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/61_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/35_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/59_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/18_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/44_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/18_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/37_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/19_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/102_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/79_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/25_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/65_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/61_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/83_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/36_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/88_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/77_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/41_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/67_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/97_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/89_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/71_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/67_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/18_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/65_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/3_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/69_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/15_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/39_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/9_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/72_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/45_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/44_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/84_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/94_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/97_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/5_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/75_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/17_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/71_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/5_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/73_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/34_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/25_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/22_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/63_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/79_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/99_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/59_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/62_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/84_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/45_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/17_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/76_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/22_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/14_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/8_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/56_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/37_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/23_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/94_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/3_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/93_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/42_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/69_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/71_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/59_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/77_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/85_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/23_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/58_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/51_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/8_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/45_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/65_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/79_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/5_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/75_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/86_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/43_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/74_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/49_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/72_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/28_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/59_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/15_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/96_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/32_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/12_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/62_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/23_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/93_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/67_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/78_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/68_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/76_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/5_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/2_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/72_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/8_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/34_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/59_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/71_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/82_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/42_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/91_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/49_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/87_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/6_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/17_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/28_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/86_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/15_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/68_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/48_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/78_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/59_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/34_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/35_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/72_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/96_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/6_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/79_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/9_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/51_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/99_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/21_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/93_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/9_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/47_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/37_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/84_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/13_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/1_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/74_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/66_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/35_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/84_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/99_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/57_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/63_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/84_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/24_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/73_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/2_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/29_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/63_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/34_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/16_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/61_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/11_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/51_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/64_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/17_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/63_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/56_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/103_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/45_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/14_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/49_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/33_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/55_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/66_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/2_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/67_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/69_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/72_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/22_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/75_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/3_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/57_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/36_0.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/54_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/92_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/21_6.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/28_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/57_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/103_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/78_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/47_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/76_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/87_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/68_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/21_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/8_5.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/14_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/13_1.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/59_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/92_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/22_8.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/37_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/32_9.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/26_4.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/98_7.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/48_3.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/42_2.npy
# /icislab/volume1/wjl/eeg/chbmit_rl/train/ecg/47_7.npy
# ...
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/68_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/84_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/1_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/88_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/31_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/52_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/92_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/33_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/84_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/8_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/22_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/27_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/98_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/23_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/41_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/77_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/64_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/6_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/29_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/61_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/54_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/9_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/18_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/54_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/34_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/41_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/5_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/63_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/17_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/4_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/101_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/39_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/1_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/27_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/23_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/66_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/4_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/72_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/103_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/15_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/81_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/29_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/5_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/98_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/15_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/21_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/76_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/16_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/67_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/37_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/44_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/103_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/19_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/7_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/8_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/74_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/1_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/35_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/55_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/16_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/27_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/45_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/55_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/49_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/14_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/81_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/99_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/47_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/54_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/89_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/45_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/8_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/54_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/59_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/85_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/78_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/41_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/75_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/71_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/51_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/65_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/12_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/103_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/79_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/53_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/95_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/28_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/91_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/102_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/35_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/13_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/101_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/9_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/23_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/68_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/46_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/1_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/86_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/4_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/42_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/62_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/102_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/66_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/22_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/16_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/102_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/62_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/65_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/67_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/32_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/99_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/11_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/61_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/97_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/84_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/103_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/37_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/46_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/53_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/27_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/42_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/64_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/22_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/22_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/19_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/53_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/68_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/32_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/48_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/99_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/71_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/93_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/51_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/12_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/29_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/3_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/3_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/37_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/83_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/32_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/58_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/45_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/99_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/92_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/4_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/68_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/12_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/96_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/14_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/11_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/73_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/9_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/66_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/77_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/19_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/26_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/98_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/59_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/16_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/73_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/2_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/71_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/49_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/62_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/67_9.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/56_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/28_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/55_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/75_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/67_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/43_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/64_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/36_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/49_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/88_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/87_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/93_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/49_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/3_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/102_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/74_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/58_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/59_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/43_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/42_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/99_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/64_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/64_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/89_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/22_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/62_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/21_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/53_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/23_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/8_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/85_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/103_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/98_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/8_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/27_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/21_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/94_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/36_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/31_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/78_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/59_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/92_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/57_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/24_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/51_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/9_3.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/58_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/47_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/46_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/37_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/51_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/76_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/64_2.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/82_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/24_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/15_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/19_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/69_0.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/67_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/82_4.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/73_1.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/31_8.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/32_7.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/8_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/41_5.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/92_6.jpg
# /icislab/volume1/wjl/eeg/chbmit_rl/train/images/stft/23_0.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17283/4138791045.py in <module>
#      74     canvas = FigureCanvas(fig)
#      75     ax = fig.gca()
# ---> 76     ax.pcolormesh(t, f, 20 * np.log10(np.abs(zxx)), shading='gouraud')
#      77     ax.axis('off')
#      78     canvas.draw()
#
# ~/.conda/envs/ecg/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.conda/envs/ecg/lib/python3.7/site-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6061
#    6062         X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
# -> 6063                                             shading=shading, kwargs=kwargs)
#    6064         coords = np.stack([X, Y], axis=-1)
#    6065         # convert to one dimensional array
#
# ~/.conda/envs/ecg/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _pcolorargs(self, funcname, shading, *args, **kwargs)
#    5548                 if isinstance(Y, np.ma.core.MaskedArray):
#    5549                     Y = Y.data
# -> 5550             nrows, ncols = C.shape
#    5551         else:
#    5552             raise TypeError(f'{funcname}() takes 1 or 3 positional arguments '
#
# ValueError: too many values to unpack (expected 2)
